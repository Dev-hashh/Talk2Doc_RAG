# %%
import sys
print(sys.executable)
# Out:
# c:\Users\dev\talk2doc\venv\Scripts\python.exe

# %%
# import requests

# response = requests.post(
#     "http://localhost:11434/api/generate",
#     json={
#         "model": "deepseek-v3.1:671b-cloud",      #llama3, glm, deepsek
#         #"prompt": "Explain transformers in 3 bullet points.",
#         #"prompt": "Use only the following information to answer the question. If you don't know the answer, say you don't know. Information: [The capital of France is Paris.] Question: What is the capital of Paris?",
#         #"prompt": "Use only the following information to answer the question. If you don't know the answer, say you don't know. Information: [The capital of France is Lyon.] Question: What is the capital of France?",   #response 'Lyon'
#             "prompt": "Use only the following information to answer the question. If you don't know the answer, say you don't know. Information:"
#             "[The capital of France is Paris."
#             "The capital of Germany is Berlin.] "
#             "Question: What is the capital ?",   
#         "stream": False
#     }
# )

# print(response.json()["response"])
# print(response.json())
# Out:
# I don't know.
# {'model': 'deepseek-v3.1:671b-cloud', 'remote_model': 'deepseek-v3.1:671b', 'remote_host': 'https://ollama.com:443', 'created_at': '2026-02-18T13:04:53.289214117Z', 'response': "I don't know.", 'done': True, 'done_reason': 'stop', 'total_duration': 358269155, 'prompt_eval_count': 51, 'eval_count': 6}
